# %% [markdown]
# ## **Cape Town South Africa Suburbs Water Consumption**
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Iamnyatichi/capetown_water_consumption/blob/main/cape_town_water.ipynb)
#
# ### **Overview**
# In 2017 and early 2018, Cape Town, SA experienced the worst drought. The town became the first large city in the world to run out of municipal water. Thus, this project analyses the water 2017 Cape Town water consumption per Suburb in Kiloliters per month.
#
# #### **Data Source**
# - The data was obtained Github [EBISYS](https://github.com/EBISYS/WaterWatch/tree/master).
#
# #### **Data Analysis**
# The data was analyzed using the following Python libraries:
# - Pandas
# - Folium for interactive map visualization.
#
# #### **Results**
# The results were visualized in 2 interactive maps showing each suburb's monthly water consumption and exported as a web pages for easy visualization and sharing.
#
# #### **Conclusion**
# This analysis can be used by the Cape Town municipality to identify areas in need of more water distribution, the South Africa government  in resources allocation, NGOs, and other organizations such as the WHO and United Nations.

# %%
#python libraries
import pandas as pd
import folium

# %%
#data loading from github EBISYS
df_suburbs=pd.read_excel('C:/Users/HomePC/Documents/GIS WORK/GIS PROJECTS/GEOPANDAS/capetown_water_consumption/waterwatch_clean2.xlsx')
df_suburbs.head()
# Out:
#    Unnamed: 0           Suburb  \
# 0           0          ATHLONE
# 1           1           AURORA
# 2           2       BANTRY BAY
# 3           3  BELLVILLE SOUTH
# 4           4        BERGVLIET
#
#    Number of single-residential properties_number  Oct 2017\nkl/month  \
# 0                                            2272                  11
# 1                                             426                  10
# 2                                             248                  13
# 3                                            2041                  11
# 4                                            1488                   8
#
#      Month  Year   Latitude  Longitude
# 0  October  2017 -33.967220  18.502140
# 1  October  2017 -32.705958  18.485135
# 2  October  2017 -33.927953  18.382592
# 3  October  2017 -33.920011  18.642819
# 4  October  2017 -34.047464  18.452499

# %%
df_suburbs.columns
# Out:
# Index(['Unnamed: 0', 'Suburb',
#        'Number of single-residential properties_number', 'Oct 2017\nkl/month',
#        'Month', 'Year', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# check rows and columns
df_suburbs.shape
# Out:
# (121, 8)

# %%
# Statistics of the data
df_suburbs.describe()
# Out:
#        Unnamed: 0  Number of single-residential properties_number  \
# count  121.000000                                      121.000000
# mean    60.000000                                     1849.983471
# std     35.073732                                     2506.756526
# min      0.000000                                        0.000000
# 25%     30.000000                                      364.000000
# 50%     60.000000                                     1009.000000
# 75%     90.000000                                     2411.000000
# max    120.000000                                    20719.000000
#
#        Oct 2017\nkl/month    Year    Latitude   Longitude
# count          121.000000   121.0  121.000000  121.000000
# mean             8.413223  2017.0  -33.944923   18.668673
# std              3.275336     0.0    0.217793    0.568946
# min              0.000000  2017.0  -34.589721   18.329108
# 25%              8.000000  2017.0  -34.037828   18.457490
# 50%              9.000000  2017.0  -33.950865   18.505041
# 75%             10.000000  2017.0  -33.908311   18.638249
# max             13.000000  2017.0  -32.705958   22.192635

# %%
# create a basic map in folium
capetown=folium.Map(location=[-33.925, 18.625],zoom_start=10)

capetown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e72a6e8d8e97120c82f6ae6f9a91e015 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e72a6e8d8e97120c82f6ae6f9a91e015&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e72a6e8d8e97120c82f6ae6f9a91e015 = L.map(
#                 &quot;map_e72a6e8d8e97120c82f6ae6f9a91e015&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9abddc65129ca0194f706c114e2949f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9abddc65129ca0194f706c114e2949f1.addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Extract latitude and longitude
df_suburbsloc=df_suburbs[['Latitude','Longitude']]
# df_suburbsloc.head()

# change df into a list
suburbs_list=df_suburbsloc.values.tolist()
suburbs_size=len(suburbs_list)  #to check the length of the suburbs, how many
suburbs_size
# Out:
# 121

# %%
# iterate through the data to plot on the map 
for point in range (0, suburbs_size):
    folium.Marker(suburbs_list[point]).add_to(capetown)

capetown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e72a6e8d8e97120c82f6ae6f9a91e015 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e72a6e8d8e97120c82f6ae6f9a91e015&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e72a6e8d8e97120c82f6ae6f9a91e015 = L.map(
#                 &quot;map_e72a6e8d8e97120c82f6ae6f9a91e015&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9abddc65129ca0194f706c114e2949f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9abddc65129ca0194f706c114e2949f1.addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             tile_layer_9abddc65129ca0194f706c114e2949f1.addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_fff87e2b41cc35fb00813cac6ac1fc6f = L.marker(
#                 [-33.96722, 18.50214],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_b4ffd5453a8984b722ade3f44de06f09 = L.marker(
#                 [-32.705958, 18.485135],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_28d0e8d26ba6440964ac47b306d6af9d = L.marker(
#                 [-33.927953, 18.382592],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_945d17ec5748affbf78de969ed6d8d53 = L.marker(
#                 [-33.920011, 18.642819],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_0ebb18f66d4d629238499b7ea82df830 = L.marker(
#                 [-34.047464, 18.452499],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_b2d86d17c371e943c4bc4140a127a287 = L.marker(
#                 [-33.947283, 18.575133],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_019c314080ea3b992e50463432519236 = L.marker(
#                 [-33.991092, 18.444217],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_e47c3ca420a52397cc4a9ca5e68df01c = L.marker(
#                 [-33.882677, 18.652075],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_820f2dbdd45787fc68a67be8f01b68cf = L.marker(
#                 [-33.950161, 18.554446],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_5b8fb7ce237c5e02b6e61a904e5d8dad = L.marker(
#                 [-33.860418, 18.544612],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_3948ac92dd2a8ff2c97360a45f822e62 = L.marker(
#                 [-34.065011, 22.06257],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_c4d7896dd6a419271e8e41c241e290a4 = L.marker(
#                 [-33.95, 18.533333],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_7fcbaf491f7dba56fd2f82339530ac57 = L.marker(
#                 [-33.90982, 18.481978],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_de65bd33b364c10cd554e5f8c3784f53 = L.marker(
#                 [-33.985847, 18.45749],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_8a6444e9828b58282e432784fd6dbb2d = L.marker(
#                 [-33.934259, 18.378476],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_1053a30725b3c7c1ff7940f4474327b4 = L.marker(
#                 [-34.124867, 18.432759],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_1f4f8c08f5191018e06b2282d22532f3 = L.marker(
#                 [-34.01832, 18.441142],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_b91eabe40ecd07e6fc70b0b1be08609c = L.marker(
#                 [-33.926369, 18.593577],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_956cae00c8b23f923ebd78544dfbb6ed = L.marker(
#                 [-33.978555, 18.50413],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_ac3d606ae53215f605ed50e3273d96c3 = L.marker(
#                 [-33.994451, 18.595982],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6

# %%
# adding pop-up message with name of suburb
for point in range (0, suburbs_size):
    folium.Marker(suburbs_list[point], popup=df_suburbs['Suburb'][point]).add_to(capetown)
    
capetown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e72a6e8d8e97120c82f6ae6f9a91e015 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e72a6e8d8e97120c82f6ae6f9a91e015&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e72a6e8d8e97120c82f6ae6f9a91e015 = L.map(
#                 &quot;map_e72a6e8d8e97120c82f6ae6f9a91e015&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9abddc65129ca0194f706c114e2949f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9abddc65129ca0194f706c114e2949f1.addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             tile_layer_9abddc65129ca0194f706c114e2949f1.addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_fff87e2b41cc35fb00813cac6ac1fc6f = L.marker(
#                 [-33.96722, 18.50214],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_b4ffd5453a8984b722ade3f44de06f09 = L.marker(
#                 [-32.705958, 18.485135],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_28d0e8d26ba6440964ac47b306d6af9d = L.marker(
#                 [-33.927953, 18.382592],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_945d17ec5748affbf78de969ed6d8d53 = L.marker(
#                 [-33.920011, 18.642819],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_0ebb18f66d4d629238499b7ea82df830 = L.marker(
#                 [-34.047464, 18.452499],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_b2d86d17c371e943c4bc4140a127a287 = L.marker(
#                 [-33.947283, 18.575133],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_019c314080ea3b992e50463432519236 = L.marker(
#                 [-33.991092, 18.444217],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_e47c3ca420a52397cc4a9ca5e68df01c = L.marker(
#                 [-33.882677, 18.652075],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_820f2dbdd45787fc68a67be8f01b68cf = L.marker(
#                 [-33.950161, 18.554446],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_5b8fb7ce237c5e02b6e61a904e5d8dad = L.marker(
#                 [-33.860418, 18.544612],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_3948ac92dd2a8ff2c97360a45f822e62 = L.marker(
#                 [-34.065011, 22.06257],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_c4d7896dd6a419271e8e41c241e290a4 = L.marker(
#                 [-33.95, 18.533333],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_7fcbaf491f7dba56fd2f82339530ac57 = L.marker(
#                 [-33.90982, 18.481978],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_de65bd33b364c10cd554e5f8c3784f53 = L.marker(
#                 [-33.985847, 18.45749],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_8a6444e9828b58282e432784fd6dbb2d = L.marker(
#                 [-33.934259, 18.378476],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_1053a30725b3c7c1ff7940f4474327b4 = L.marker(
#                 [-34.124867, 18.432759],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_1f4f8c08f5191018e06b2282d22532f3 = L.marker(
#                 [-34.01832, 18.441142],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_b91eabe40ecd07e6fc70b0b1be08609c = L.marker(
#                 [-33.926369, 18.593577],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_956cae00c8b23f923ebd78544dfbb6ed = L.marker(
#                 [-33.978555, 18.50413],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_ac3d606ae53215f605ed50e3273d96c3 = L.marker(
#                 [-33.994451, 18.595982],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6

# %%
# Classifying Markers for easy visualization

for point in range (0, suburbs_size):
    if df_suburbs['Oct 2017\nkl/month'][point]<=5:
        folium.Marker(suburbs_list[point], popup=df_suburbs['Suburb'][point]+ ':'+ str(df_suburbs['Oct 2017\nkl/month'][point])+' kL', icon=folium.Icon(color='green', icon_color='white',icon='thumbs-up', angle=0, prefix='fa')).add_to(capetown)
        
    elif df_suburbs['Oct 2017\nkl/month'][point]>5 and df_suburbs['Oct 2017\nkl/month'][point]<=8:
        folium.Marker(suburbs_list[point], popup=df_suburbs['Suburb'][point]+ ':'+ str(df_suburbs['Oct 2017\nkl/month'][point])+' kL', icon=folium.Icon(color='blue', icon_color='white',icon='thumbs-up', angle=0, prefix='fa')).add_to(capetown)
    else:
        folium.Marker(suburbs_list[point], popup=df_suburbs['Suburb'][point]+ ':'+ str(df_suburbs['Oct 2017\nkl/month'][point])+' kL', icon=folium.Icon(color='red', icon_color='white',icon='thumbs-down', angle=0, prefix='fa')).add_to(capetown)

# Define the legend's HTML
legend_html = '''
<div style="position: fixed; 
     top: 10px; right: 10px; width: 200px; height: 100px; padding-top:5px;
     border:2px solid grey; z-index:9999; font-size:14px;
     background-color:white; opacity: 0.85;">
     &nbsp; 
    <b>Legend</b> <br>
    <i class="fa fa-circle" style="color:green; margin-left:5px"></i> Green Thumbs Up: <= 5kl <br>
    <i class="fa fa-circle" style="color:#87CEEB; margin-left:5px"></i> Blue Thumbs Up: <=8kl <br>
    <i class="fa fa-circle" style="color:red; margin-left:5px"></i> Red Thumbs Down: >8kl    
    
</div>
'''

# Add the legend to the map
capetown.get_root().html.add_child(folium.Element(legend_html))
# capetown.save('index.html')   
capetown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e72a6e8d8e97120c82f6ae6f9a91e015 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e72a6e8d8e97120c82f6ae6f9a91e015&quot; &gt;&lt;/div&gt;
#
#
# &lt;div style=&quot;position: fixed;
#      top: 10px; right: 10px; width: 200px; height: 100px; padding-top:5px;
#      border:2px solid grey; z-index:9999; font-size:14px;
#      background-color:white; opacity: 0.85;&quot;&gt;
#      &amp;nbsp;
#     &lt;b&gt;Legend&lt;/b&gt; &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:green; margin-left:5px&quot;&gt;&lt;/i&gt; Green Thumbs Up: &lt;= 5kl &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:#87CEEB; margin-left:5px&quot;&gt;&lt;/i&gt; Blue Thumbs Up: &lt;=8kl &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red; margin-left:5px&quot;&gt;&lt;/i&gt; Red Thumbs Down: &gt;8kl
#
# &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e72a6e8d8e97120c82f6ae6f9a91e015 = L.map(
#                 &quot;map_e72a6e8d8e97120c82f6ae6f9a91e015&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9abddc65129ca0194f706c114e2949f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9abddc65129ca0194f706c114e2949f1.addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             tile_layer_9abddc65129ca0194f706c114e2949f1.addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_fff87e2b41cc35fb00813cac6ac1fc6f = L.marker(
#                 [-33.96722, 18.50214],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_b4ffd5453a8984b722ade3f44de06f09 = L.marker(
#                 [-32.705958, 18.485135],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_28d0e8d26ba6440964ac47b306d6af9d = L.marker(
#                 [-33.927953, 18.382592],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_945d17ec5748affbf78de969ed6d8d53 = L.marker(
#                 [-33.920011, 18.642819],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_0ebb18f66d4d629238499b7ea82df830 = L.marker(
#                 [-34.047464, 18.452499],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_b2d86d17c371e943c4bc4140a127a287 = L.marker(
#                 [-33.947283, 18.575133],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_019c314080ea3b992e50463432519236 = L.marker(
#                 [-33.991092, 18.444217],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_e47c3ca420a52397cc4a9ca5e68df01c = L.marker(
#                 [-33.882677, 18.652075],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_820f2dbdd45787fc68a67be8f01b68cf = L.marker(
#                 [-33.950161, 18.554446],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_5b8fb7ce237c5e02b6e61a904e5d8dad = L.marker(
#                 [-33.860418, 18.544612],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_3948ac92dd2a8ff2c97360a45f822e62 = L.marker(
#                 [-34.065011, 22.06257],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_c4d7896dd6a419271e8e41c241e290a4 = L.marker(
#                 [-33.95, 18.533333],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_7fcbaf491f7dba56fd2f82339530ac57 = L.marker(
#                 [-33.90982, 18.481978],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_de65bd33b364c10cd554e5f8c3784f53 = L.marker(
#                 [-33.985847, 18.45749],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_8a6444e9828b58282e432784fd6dbb2d = L.marker(
#                 [-33.934259, 18.378476],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_1053a30725b3c7c1ff7940f4474327b4 = L.marker(
#                 [-34.124867, 18.432759],
#                 {
# }
#             ).addTo(map_e72a6e8d8e97120c82f6ae6f9a91e015);
#
#
#             var marker_1f4f8c08f5191018e06b2282d22532f3 = L.marke

# %%
#visualizing in a point map
capetown2= folium.Map(location=[-33.925, 18.625],zoom_start=11)

#Adding More Basemaps
folium.TileLayer("CartoDB Positron").add_to(capetown2)
folium.TileLayer("CartoDB Dark_matter").add_to(capetown2)
folium.TileLayer(show=False).add_to(capetown2)

folium.LayerControl().add_to(capetown2)

#Classification
for point in range (0, suburbs_size):
    folium.Circle(
        location=suburbs_list[point],
        popup=df_suburbs['Suburb'][point]+ ':'+ str(df_suburbs['Oct 2017\nkl/month'][point])+' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point]* 100),
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0,
        ).add_to(capetown2)


#Classifying Points for visualization

for point in range(0, suburbs_size):
    if df_suburbs['Oct 2017\nkl/month'][point]<=8 and df_suburbs['Oct 2017\nkl/month'][point]>0:
        usage_color='green'
    elif df_suburbs['Oct 2017\nkl/month'][point]>8 and df_suburbs['Oct 2017\nkl/month'][point]<=10:
        usage_color='#17cbef'
    elif df_suburbs['Oct 2017\nkl/month'][point]>10:
        usage_color='red'
    else: # Outliers
        usage_color='orange'

    folium.Circle(
        location=suburbs_list[point],
        popup=df_suburbs['Suburb'][point]+ ':'+ str(df_suburbs['Oct 2017\nkl/month'][point])+' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point]*100),
        color=usage_color,
        fill=True,
        opacity=0.8,
        fill_color=usage_color,
        stroke=True,
        weight=1.0        
    ).add_to(capetown2)

# Define the legend's HTML
legend_html = '''
<div style="position: fixed; 
     top: 10px; right: 10px; width: 200px; height: 100px; padding-top:5px;
     border:2px solid grey; z-index:9999; font-size:14px;
     background-color:white; opacity: 0.85;">
     &nbsp; 
    <b>Legend</b> <br>
    <i class="fa fa-circle" style="color:green; margin-left:5px"></i> Green Circle: <= 5kl <br>
    <i class="fa fa-circle" style="color:#87CEEB; margin-left:5px"></i> Blue Circle: <=8kl <br>
    <i class="fa fa-circle" style="color:red; margin-left:5px"></i> Red Circle: >8kl    
    
</div>
'''

# Add the legend to the map
capetown2.get_root().html.add_child(folium.Element(legend_html))

# capetown2.save('capetown2.html')
capetown2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97621d80f707ce939eabdbf14a61ee24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#      top: 10px; right: 10px; width: 200px; height: 100px; padding-top:5px;
#      border:2px solid grey; z-index:9999; font-size:14px;
#      background-color:white; opacity: 0.85;&quot;&gt;
#      &amp;nbsp;
#     &lt;b&gt;Legend&lt;/b&gt; &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:green; margin-left:5px&quot;&gt;&lt;/i&gt; Green Circle: &lt;= 5kl &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:#87CEEB; margin-left:5px&quot;&gt;&lt;/i&gt; Blue Circle: &lt;=8kl &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red; margin-left:5px&quot;&gt;&lt;/i&gt; Red Circle: &gt;8kl
#
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97621d80f707ce939eabdbf14a61ee24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97621d80f707ce939eabdbf14a61ee24 = L.map(
#                 &quot;map_97621d80f707ce939eabdbf14a61ee24&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33e26bcc3b807dfbfb624658b2c59dca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_33e26bcc3b807dfbfb624658b2c59dca.addTo(map_97621d80f707ce939eabdbf14a61ee24);
#
#
#             var tile_layer_36413bf9b4d7823937f6c9f75a4660d6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36413bf9b4d7823937f6c9f75a4660d6.addTo(map_97621d80f707ce939eabdbf14a61ee24);
#
#
#             var tile_layer_7eed815e442e32d94d14fbed643e7688 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7eed815e442e32d94d14fbed643e7688.addTo(map_97621d80f707ce939eabdbf14a61ee24);
#
#
#             var tile_layer_7815e3133b6e4be79ad837dd37c3aa0e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var layer_control_8fe51f8850b87afd11872c043208d70b_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_7815e3133b6e4be79ad837dd37c3aa0e,
#                     &quot;cartodbpositron&quot; : tile_layer_36413bf9b4d7823937f6c9f75a4660d6,
#                     &quot;cartodbdarkmatter&quot; : tile_layer_7eed815e442e32d94d14fbed643e7688,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_8fe51f8850b87afd11872c043208d70b = L.control.layers(
#                 layer_control_8fe51f8850b87afd11872c043208d70b_layers.base_layers,
#                 layer_control_8fe51f8850b87afd11872c043208d70b_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_97621d80f707ce939eabdbf14a61ee24);
#
#
#
#             var circle_3cf95dd8741a587723cac4c16b6d5b30 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &q

# %%
#Capetown Heatmap
from folium.plugins import HeatMap
# plot points on the heat map
capetown3= folium.Map(location=[-33.925, 18.625], tiles='CartoDB Dark_matter', zoom_start=11)

for point in range (0, suburbs_size):
    folium.Circle(
      location=suburbs_list[point],
      radius='15',
      color='#17cbef',
      fill=True,
    	opacity=0.8,
      fill_color='#17cbef',
      stroke=True,
      weight=1.0
      ).add_to(capetown3)
                                                      
#  create an array
suburbsArray=df_suburbs[['Latitude','Longitude']].values

# plot on the heat map
capetown3.add_child(HeatMap(suburbsArray))

# Define the legend's HTML
legend_html = '''
<div style="position: fixed; 
     bottom: 10px; right: 10px; width: 200px; height: 100px; padding-top:5px;
     border:2px solid grey; z-index:9999; font-size:14px;
     background-color:white; opacity: 0.85;">
     &nbsp; 
    <b>Water Consumption</b> <br>
    <i class="fa fa-circle" style="color:green; margin-left:5px"></i> Green Color: <= 5kl <br>
    <i class="fa fa-circle" style="color:#87CEEB; margin-left:5px"></i> Blue Color: <=8kl <br>
    <i class="fa fa-circle" style="color:red; margin-left:5px"></i> Red Color: >8kl    
    
</div>
'''

# Add the legend to the map
capetown3.get_root().html.add_child(folium.Element(legend_html))
# capetown3.save('capetown3.html')
capetown3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3613afdac54609905e1c2c8c0b71aa53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#      bottom: 10px; right: 10px; width: 200px; height: 100px; padding-top:5px;
#      border:2px solid grey; z-index:9999; font-size:14px;
#      background-color:white; opacity: 0.85;&quot;&gt;
#      &amp;nbsp;
#     &lt;b&gt;Water Consumption&lt;/b&gt; &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:green; margin-left:5px&quot;&gt;&lt;/i&gt; Green Color: &lt;= 5kl &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:#87CEEB; margin-left:5px&quot;&gt;&lt;/i&gt; Blue Color: &lt;=8kl &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red; margin-left:5px&quot;&gt;&lt;/i&gt; Red Color: &gt;8kl
#
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3613afdac54609905e1c2c8c0b71aa53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3613afdac54609905e1c2c8c0b71aa53 = L.map(
#                 &quot;map_3613afdac54609905e1c2c8c0b71aa53&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb02990db2936149f6d61632181fa847 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb02990db2936149f6d61632181fa847.addTo(map_3613afdac54609905e1c2c8c0b71aa53);
#
#
#             var circle_2a623123d46f781c8c8936c69f3db3d0 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_3613afdac54609905e1c2c8c0b71aa53);
#
#
#             var circle_662834856bf53427d1d14e1bfe01792a = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_3613afdac54609905e1c2c8c0b71aa53);
#
#
#             var circle_7488a85e2fadcccb687727a7950eb8d5 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_3613afdac54609905e1c2c8c0b71aa53);
#
#
#             var circle_78e219a43a387b1f1aceb637c43d55de = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_3613afdac54609905e1c2c8c0b71aa53);
#
#
#             var circle_ce9cd033b87825f7131a4b1c57a40f49 = L.circle(
#                 [-34.047464, 18.452499],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoi

# %% [markdown]
# ## **THE END**
