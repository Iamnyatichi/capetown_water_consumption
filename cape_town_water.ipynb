# %% [markdown]
# ## **Cape Town South Africa Suburbs Water Consumption**
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/notebooks/basic_features_overview.ipynb)
#
# ### **Overview**
# In 2017 and early 2018, Cape Town, SA experienced the worst drought. The town became the first large city in the world to run out of municipal water. Thus, this project analyses the water 2017 Cape Town water consumption per Suburb in Kiloliters per month.
#
# #### **Data Source**
# - The data was obtained Github [EBISYS](https://github.com/EBISYS/WaterWatch/tree/master).
#
# #### **Data Analysis**
# The data was analyzed using the following Python libraries:
# - Pandas
# - Folium for interactive map visualization.
#
# #### **Results**
# The results were visualized in 2 interactive maps showing each suburb's monthly water consumption and exported as a web pages for easy visualization and sharing.
#
# #### **Conclusion**
# This analysis can be used by the Cape Town municipality to identify areas in need of more water distribution, the South Africa government  in resources allocation, NGOs, and other organizations such as the WHO and United Nations.

# %%
#python libraries
import pandas as pd
import folium

# %%
#data loading from github EBISYS
df_suburbs=pd.read_excel('C:/Users/HomePC/Documents/GIS WORK/GIS PROJECTS/FOLIUM/waterwatch_clean2.xlsx')
df_suburbs.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #data loading from github EBISYS
# ----> 2 df_suburbs=pd.read_excel('C:/Users/HomePC/Documents/GIS WORK/GIS PROJECTS/FOLIUM/waterwatch_clean2.xlsx')
#       3 df_suburbs.head()
#
# File c:\Users\HomePC\miniconda3\envs\geo_new\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\HomePC\miniconda3\envs\geo_new\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File c:\Users\HomePC\miniconda3\envs\geo_new\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File c:\Users\HomePC\miniconda3\envs\geo_new\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/HomePC/Documents/GIS WORK/GIS PROJECTS/FOLIUM/waterwatch_clean2.xlsx'

# %%
df_suburbs.columns
# Out:
# Index(['Unnamed: 0', 'Suburb',
#        'Number of single-residential properties_number', 'Oct 2017\nkl/month',
#        'Month', 'Year', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# check rows and columns
df_suburbs.shape
# Out:
# (121, 8)

# %%
# Statistics of the data
df_suburbs.describe()
# Out:
#        Unnamed: 0  Number of single-residential properties_number  \
# count  121.000000                                      121.000000
# mean    60.000000                                     1849.983471
# std     35.073732                                     2506.756526
# min      0.000000                                        0.000000
# 25%     30.000000                                      364.000000
# 50%     60.000000                                     1009.000000
# 75%     90.000000                                     2411.000000
# max    120.000000                                    20719.000000
#
#        Oct 2017\nkl/month    Year    Latitude   Longitude
# count          121.000000   121.0  121.000000  121.000000
# mean             8.413223  2017.0  -33.944923   18.668673
# std              3.275336     0.0    0.217793    0.568946
# min              0.000000  2017.0  -34.589721   18.329108
# 25%              8.000000  2017.0  -34.037828   18.457490
# 50%              9.000000  2017.0  -33.950865   18.505041
# 75%             10.000000  2017.0  -33.908311   18.638249
# max             13.000000  2017.0  -32.705958   22.192635

# %%
# create a basic map in folium
capetown=folium.Map(location=[-33.925, 18.625],zoom_start=10)

capetown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3de8c4f89af53a3973f9d007698ad4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3de8c4f89af53a3973f9d007698ad4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3de8c4f89af53a3973f9d007698ad4c = L.map(
#                 &quot;map_d3de8c4f89af53a3973f9d007698ad4c&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f104b42f497ced51ccf815af492da01 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f104b42f497ced51ccf815af492da01.addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Extract latitude and longitude
df_suburbsloc=df_suburbs[['Latitude','Longitude']]
# df_suburbsloc.head()

# change df into a list
suburbs_list=df_suburbsloc.values.tolist()
suburbs_size=len(suburbs_list)  #to check the length of the suburbs, how many
suburbs_size
# Out:
# 121

# %%
# iterate through the data to plot on the map 
for point in range (0, suburbs_size):
    folium.Marker(suburbs_list[point]).add_to(capetown)

capetown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3de8c4f89af53a3973f9d007698ad4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3de8c4f89af53a3973f9d007698ad4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3de8c4f89af53a3973f9d007698ad4c = L.map(
#                 &quot;map_d3de8c4f89af53a3973f9d007698ad4c&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f104b42f497ced51ccf815af492da01 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f104b42f497ced51ccf815af492da01.addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             tile_layer_3f104b42f497ced51ccf815af492da01.addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_4b3c9dbe4b7f2c491ad052b789a8bd48 = L.marker(
#                 [-33.96722, 18.50214],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_2ad5a0148e671a5aaa644dab30ff4f9c = L.marker(
#                 [-32.705958, 18.485135],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_8023441e6d5a2af4b2d22bb793e6b8c5 = L.marker(
#                 [-33.927953, 18.382592],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_d2f023357df9a6b6e06d19e3e0f097f7 = L.marker(
#                 [-33.920011, 18.642819],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_ee1bd2f368fff557cc06934a7dddec84 = L.marker(
#                 [-34.047464, 18.452499],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_6f2e2d969b6920edaf6c465315a64959 = L.marker(
#                 [-33.947283, 18.575133],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_45861acd172927b0fda20608ba5f2ece = L.marker(
#                 [-33.991092, 18.444217],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_f6909ed13a710406fa9279a039fab396 = L.marker(
#                 [-33.882677, 18.652075],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_5361ac931c61ae6191ca44e908a6d85c = L.marker(
#                 [-33.950161, 18.554446],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_7a36da7b4019df1f726b39e245fd87e7 = L.marker(
#                 [-33.860418, 18.544612],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_743499259bfdf6204e548eed6cf367bb = L.marker(
#                 [-34.065011, 22.06257],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_d6c6533fcdd7336367b077694a0ee05b = L.marker(
#                 [-33.95, 18.533333],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_23c2f6a1781cadce8df743abf9056064 = L.marker(
#                 [-33.90982, 18.481978],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_b44ff67800d5e66443c1730a0b81471c = L.marker(
#                 [-33.985847, 18.45749],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_0378054fc318a982241c7774839195bb = L.marker(
#                 [-33.934259, 18.378476],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_9c9ddd88f455b77650dc074c474c616f = L.marker(
#                 [-34.124867, 18.432759],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_a80aa9a6bd86f1248693ea98eb795424 = L.marker(
#                 [-34.01832, 18.441142],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_ab453b63eeb5b37ff4d39217118f726f = L.marker(
#                 [-33.926369, 18.593577],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_3452e59c77568eec26eeafdf6f02db51 = L.marker(
#                 [-33.978555, 18.50413],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_e8ec6d18835a2214665b05634825027f = L.marker(
#                 [-33.994451, 18.595982],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d0

# %%
# adding pop-up message with name of suburb
for point in range (0, suburbs_size):
    folium.Marker(suburbs_list[point], popup=df_suburbs['Suburb'][point]).add_to(capetown)
    
capetown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3de8c4f89af53a3973f9d007698ad4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3de8c4f89af53a3973f9d007698ad4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3de8c4f89af53a3973f9d007698ad4c = L.map(
#                 &quot;map_d3de8c4f89af53a3973f9d007698ad4c&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f104b42f497ced51ccf815af492da01 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f104b42f497ced51ccf815af492da01.addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             tile_layer_3f104b42f497ced51ccf815af492da01.addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_4b3c9dbe4b7f2c491ad052b789a8bd48 = L.marker(
#                 [-33.96722, 18.50214],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_2ad5a0148e671a5aaa644dab30ff4f9c = L.marker(
#                 [-32.705958, 18.485135],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_8023441e6d5a2af4b2d22bb793e6b8c5 = L.marker(
#                 [-33.927953, 18.382592],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_d2f023357df9a6b6e06d19e3e0f097f7 = L.marker(
#                 [-33.920011, 18.642819],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_ee1bd2f368fff557cc06934a7dddec84 = L.marker(
#                 [-34.047464, 18.452499],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_6f2e2d969b6920edaf6c465315a64959 = L.marker(
#                 [-33.947283, 18.575133],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_45861acd172927b0fda20608ba5f2ece = L.marker(
#                 [-33.991092, 18.444217],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_f6909ed13a710406fa9279a039fab396 = L.marker(
#                 [-33.882677, 18.652075],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_5361ac931c61ae6191ca44e908a6d85c = L.marker(
#                 [-33.950161, 18.554446],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_7a36da7b4019df1f726b39e245fd87e7 = L.marker(
#                 [-33.860418, 18.544612],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_743499259bfdf6204e548eed6cf367bb = L.marker(
#                 [-34.065011, 22.06257],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_d6c6533fcdd7336367b077694a0ee05b = L.marker(
#                 [-33.95, 18.533333],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_23c2f6a1781cadce8df743abf9056064 = L.marker(
#                 [-33.90982, 18.481978],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_b44ff67800d5e66443c1730a0b81471c = L.marker(
#                 [-33.985847, 18.45749],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_0378054fc318a982241c7774839195bb = L.marker(
#                 [-33.934259, 18.378476],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_9c9ddd88f455b77650dc074c474c616f = L.marker(
#                 [-34.124867, 18.432759],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_a80aa9a6bd86f1248693ea98eb795424 = L.marker(
#                 [-34.01832, 18.441142],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_ab453b63eeb5b37ff4d39217118f726f = L.marker(
#                 [-33.926369, 18.593577],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_3452e59c77568eec26eeafdf6f02db51 = L.marker(
#                 [-33.978555, 18.50413],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_e8ec6d18835a2214665b05634825027f = L.marker(
#                 [-33.994451, 18.595982],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d0

# %%
# Classifying Markers for easy visualization

for point in range (0, suburbs_size):
    if df_suburbs['Oct 2017\nkl/month'][point]<=5:
        folium.Marker(suburbs_list[point], popup=df_suburbs['Suburb'][point]+ ':'+ str(df_suburbs['Oct 2017\nkl/month'][point])+' kL', icon=folium.Icon(color='green', icon_color='white',icon='thumbs-up', angle=0, prefix='fa')).add_to(capetown)
        
    elif df_suburbs['Oct 2017\nkl/month'][point]>5 and df_suburbs['Oct 2017\nkl/month'][point]<=8:
        folium.Marker(suburbs_list[point], popup=df_suburbs['Suburb'][point]+ ':'+ str(df_suburbs['Oct 2017\nkl/month'][point])+' kL', icon=folium.Icon(color='blue', icon_color='white',icon='thumbs-up', angle=0, prefix='fa')).add_to(capetown)
    else:
        folium.Marker(suburbs_list[point], popup=df_suburbs['Suburb'][point]+ ':'+ str(df_suburbs['Oct 2017\nkl/month'][point])+' kL', icon=folium.Icon(color='red', icon_color='white',icon='thumbs-down', angle=0, prefix='fa')).add_to(capetown)

# Define the legend's HTML
legend_html = '''
<div style="position: fixed; 
     top: 10px; right: 10px; width: 200px; height: 100px; padding-top:5px;
     border:2px solid grey; z-index:9999; font-size:14px;
     background-color:white; opacity: 0.85;">
     &nbsp; 
    <b>Legend</b> <br>
    <i class="fa fa-circle" style="color:green; margin-left:5px"></i> Green Thumbs Up: <= 5kl <br>
    <i class="fa fa-circle" style="color:#87CEEB; margin-left:5px"></i> Blue Thumbs Up: <=8kl <br>
    <i class="fa fa-circle" style="color:red; margin-left:5px"></i> Red Thumbs Down: >8kl    
    
</div>
'''

# Add the legend to the map
capetown.get_root().html.add_child(folium.Element(legend_html))
# capetown.save('index.html')   
capetown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3de8c4f89af53a3973f9d007698ad4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3de8c4f89af53a3973f9d007698ad4c&quot; &gt;&lt;/div&gt;
#
#
# &lt;div style=&quot;position: fixed;
#      top: 10px; right: 10px; width: 200px; height: 100px; padding-top:5px;
#      border:2px solid grey; z-index:9999; font-size:14px;
#      background-color:white; opacity: 0.85;&quot;&gt;
#      &amp;nbsp;
#     &lt;b&gt;Legend&lt;/b&gt; &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:green; margin-left:5px&quot;&gt;&lt;/i&gt; Green Thumbs Up: &lt;= 5kl &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:#87CEEB; margin-left:5px&quot;&gt;&lt;/i&gt; Blue Thumbs Up: &lt;=8kl &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red; margin-left:5px&quot;&gt;&lt;/i&gt; Red Thumbs Down: &gt;8kl
#
# &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3de8c4f89af53a3973f9d007698ad4c = L.map(
#                 &quot;map_d3de8c4f89af53a3973f9d007698ad4c&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f104b42f497ced51ccf815af492da01 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f104b42f497ced51ccf815af492da01.addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             tile_layer_3f104b42f497ced51ccf815af492da01.addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_4b3c9dbe4b7f2c491ad052b789a8bd48 = L.marker(
#                 [-33.96722, 18.50214],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_2ad5a0148e671a5aaa644dab30ff4f9c = L.marker(
#                 [-32.705958, 18.485135],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_8023441e6d5a2af4b2d22bb793e6b8c5 = L.marker(
#                 [-33.927953, 18.382592],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_d2f023357df9a6b6e06d19e3e0f097f7 = L.marker(
#                 [-33.920011, 18.642819],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_ee1bd2f368fff557cc06934a7dddec84 = L.marker(
#                 [-34.047464, 18.452499],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_6f2e2d969b6920edaf6c465315a64959 = L.marker(
#                 [-33.947283, 18.575133],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_45861acd172927b0fda20608ba5f2ece = L.marker(
#                 [-33.991092, 18.444217],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_f6909ed13a710406fa9279a039fab396 = L.marker(
#                 [-33.882677, 18.652075],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_5361ac931c61ae6191ca44e908a6d85c = L.marker(
#                 [-33.950161, 18.554446],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_7a36da7b4019df1f726b39e245fd87e7 = L.marker(
#                 [-33.860418, 18.544612],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_743499259bfdf6204e548eed6cf367bb = L.marker(
#                 [-34.065011, 22.06257],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_d6c6533fcdd7336367b077694a0ee05b = L.marker(
#                 [-33.95, 18.533333],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_23c2f6a1781cadce8df743abf9056064 = L.marker(
#                 [-33.90982, 18.481978],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_b44ff67800d5e66443c1730a0b81471c = L.marker(
#                 [-33.985847, 18.45749],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_0378054fc318a982241c7774839195bb = L.marker(
#                 [-33.934259, 18.378476],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_9c9ddd88f455b77650dc074c474c616f = L.marker(
#                 [-34.124867, 18.432759],
#                 {
# }
#             ).addTo(map_d3de8c4f89af53a3973f9d007698ad4c);
#
#
#             var marker_a80aa9a6bd86f1248693ea98eb795424 = L.marke

# %%
#visualizing in a point map
capetown2= folium.Map(location=[-33.925, 18.625],zoom_start=11)

#Adding More Basemaps
folium.TileLayer("CartoDB Positron").add_to(capetown2)
folium.TileLayer("CartoDB Dark_matter").add_to(capetown2)
folium.TileLayer(show=False).add_to(capetown2)

folium.LayerControl().add_to(capetown2)

#Classification
for point in range (0, suburbs_size):
    folium.Circle(
        location=suburbs_list[point],
        popup=df_suburbs['Suburb'][point]+ ':'+ str(df_suburbs['Oct 2017\nkl/month'][point])+' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point]* 100),
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0,
        ).add_to(capetown2)


#Classifying Points for visualization

for point in range(0, suburbs_size):
    if df_suburbs['Oct 2017\nkl/month'][point]<=8 and df_suburbs['Oct 2017\nkl/month'][point]>0:
        usage_color='green'
    elif df_suburbs['Oct 2017\nkl/month'][point]>8 and df_suburbs['Oct 2017\nkl/month'][point]<=10:
        usage_color='#17cbef'
    elif df_suburbs['Oct 2017\nkl/month'][point]>10:
        usage_color='red'
    else: # Outliers
        usage_color='orange'

    folium.Circle(
        location=suburbs_list[point],
        popup=df_suburbs['Suburb'][point]+ ':'+ str(df_suburbs['Oct 2017\nkl/month'][point])+' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point]*100),
        color=usage_color,
        fill=True,
        opacity=0.8,
        fill_color=usage_color,
        stroke=True,
        weight=1.0        
    ).add_to(capetown2)

# Define the legend's HTML
legend_html = '''
<div style="position: fixed; 
     top: 10px; right: 10px; width: 200px; height: 100px; padding-top:5px;
     border:2px solid grey; z-index:9999; font-size:14px;
     background-color:white; opacity: 0.85;">
     &nbsp; 
    <b>Legend</b> <br>
    <i class="fa fa-circle" style="color:green; margin-left:5px"></i> Green Circle: <= 5kl <br>
    <i class="fa fa-circle" style="color:#87CEEB; margin-left:5px"></i> Blue Circle: <=8kl <br>
    <i class="fa fa-circle" style="color:red; margin-left:5px"></i> Red Circle: >8kl    
    
</div>
'''

# Add the legend to the map
capetown2.get_root().html.add_child(folium.Element(legend_html))

# capetown2.save('capetown2.html')
capetown2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b15c94c2836ce2b769e12bb07034751 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#      top: 10px; right: 10px; width: 200px; height: 100px; padding-top:5px;
#      border:2px solid grey; z-index:9999; font-size:14px;
#      background-color:white; opacity: 0.85;&quot;&gt;
#      &amp;nbsp;
#     &lt;b&gt;Legend&lt;/b&gt; &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:green; margin-left:5px&quot;&gt;&lt;/i&gt; Green Circle: &lt;= 5kl &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:#87CEEB; margin-left:5px&quot;&gt;&lt;/i&gt; Blue Circle: &lt;=8kl &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red; margin-left:5px&quot;&gt;&lt;/i&gt; Red Circle: &gt;8kl
#
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b15c94c2836ce2b769e12bb07034751&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b15c94c2836ce2b769e12bb07034751 = L.map(
#                 &quot;map_3b15c94c2836ce2b769e12bb07034751&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_100f9e2d4e2a26e7466f84a13e0cce39 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_100f9e2d4e2a26e7466f84a13e0cce39.addTo(map_3b15c94c2836ce2b769e12bb07034751);
#
#
#             var tile_layer_87d4b819f8df052e2c93073fd3a94aa0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_87d4b819f8df052e2c93073fd3a94aa0.addTo(map_3b15c94c2836ce2b769e12bb07034751);
#
#
#             var tile_layer_2608214db4c403b7c8fc108b7b67a1f5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2608214db4c403b7c8fc108b7b67a1f5.addTo(map_3b15c94c2836ce2b769e12bb07034751);
#
#
#             var tile_layer_3c1f5291843cb1ca4a4c6ccbd6303106 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var layer_control_35ff0196aa6468fc323d68da6173fcef_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_3c1f5291843cb1ca4a4c6ccbd6303106,
#                     &quot;cartodbpositron&quot; : tile_layer_87d4b819f8df052e2c93073fd3a94aa0,
#                     &quot;cartodbdarkmatter&quot; : tile_layer_2608214db4c403b7c8fc108b7b67a1f5,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_35ff0196aa6468fc323d68da6173fcef = L.control.layers(
#                 layer_control_35ff0196aa6468fc323d68da6173fcef_layers.base_layers,
#                 layer_control_35ff0196aa6468fc323d68da6173fcef_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_3b15c94c2836ce2b769e12bb07034751);
#
#
#
#             var circle_a6abbedbc23b41c6bdc260a2e764f5a3 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &q

# %%
#Capetown Heatmap
from folium.plugins import HeatMap
# plot points on the heat map
capetown3= folium.Map(location=[-33.925, 18.625], tiles='CartoDB Dark_matter', zoom_start=11)

for point in range (0, suburbs_size):
    folium.Circle(
      location=suburbs_list[point],
      radius='15',
      color='#17cbef',
      fill=True,
    	opacity=0.8,
      fill_color='#17cbef',
      stroke=True,
      weight=1.0
      ).add_to(capetown3)
                                                      
#  create an array
suburbsArray=df_suburbs[['Latitude','Longitude']].values

# plot on the heat map
capetown3.add_child(HeatMap(suburbsArray))

# Define the legend's HTML
legend_html = '''
<div style="position: fixed; 
     bottom: 10px; right: 10px; width: 200px; height: 100px; padding-top:5px;
     border:2px solid grey; z-index:9999; font-size:14px;
     background-color:white; opacity: 0.85;">
     &nbsp; 
    <b>Water Consumption</b> <br>
    <i class="fa fa-circle" style="color:green; margin-left:5px"></i> Green Color: <= 5kl <br>
    <i class="fa fa-circle" style="color:#87CEEB; margin-left:5px"></i> Blue Color: <=8kl <br>
    <i class="fa fa-circle" style="color:red; margin-left:5px"></i> Red Color: >8kl    
    
</div>
'''

# Add the legend to the map
capetown3.get_root().html.add_child(folium.Element(legend_html))
# capetown3.save('capetown3.html')
capetown3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9877517337932d99f0fb09803f8eadd0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#      bottom: 10px; right: 10px; width: 200px; height: 100px; padding-top:5px;
#      border:2px solid grey; z-index:9999; font-size:14px;
#      background-color:white; opacity: 0.85;&quot;&gt;
#      &amp;nbsp;
#     &lt;b&gt;Water Consumption&lt;/b&gt; &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:green; margin-left:5px&quot;&gt;&lt;/i&gt; Green Color: &lt;= 5kl &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:#87CEEB; margin-left:5px&quot;&gt;&lt;/i&gt; Blue Color: &lt;=8kl &lt;br&gt;
#     &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red; margin-left:5px&quot;&gt;&lt;/i&gt; Red Color: &gt;8kl
#
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9877517337932d99f0fb09803f8eadd0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9877517337932d99f0fb09803f8eadd0 = L.map(
#                 &quot;map_9877517337932d99f0fb09803f8eadd0&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d692ccb0b7226941ff781f5c858ec91 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d692ccb0b7226941ff781f5c858ec91.addTo(map_9877517337932d99f0fb09803f8eadd0);
#
#
#             var circle_c4c06e2de720651d63b712d352d770f2 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_9877517337932d99f0fb09803f8eadd0);
#
#
#             var circle_f7ef31ffeb53fc8246f93def7fbb9beb = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_9877517337932d99f0fb09803f8eadd0);
#
#
#             var circle_613ac04393227dace8c0197d7bde8d2c = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_9877517337932d99f0fb09803f8eadd0);
#
#
#             var circle_abc0eb43006dd2e081abd6afec55bd99 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_9877517337932d99f0fb09803f8eadd0);
#
#
#             var circle_9460e52be4456747502fb1acbfcbca6b = L.circle(
#                 [-34.047464, 18.452499],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoi

# %% [markdown]
# ## **THE END**
